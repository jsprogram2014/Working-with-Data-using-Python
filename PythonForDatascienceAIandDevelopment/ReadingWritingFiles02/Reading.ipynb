# %%
with open("example.txt",'r') as file1:
    print(file1.read())
# Out:
# messi is the goat
# in all universe

# %%
with open("example.txt",'r') as file1:
    print(file1.readline())
# Out:
# messi is the goat

# %%
with open("example.txt",'r') as file1:
    print(file1.readline())
    print(file1.readline())
    print(file1.readline())
# Out:
# satoro gojo is the strongest
#
# in all universe
#
# in all eternity

# %%
with open("example.txt",'r') as file1:
    filestuff=file1.readline()
    filestuff=file1.readline()
    filestuff=file1.readline()
    print(filestuff)
# Out:
# in all eternity

# %%
with open("example.txt",'r') as file1:
    filestuff=file1.readline(6)
    print(filestuff)
    filestuff=file1.readline(20)
    print(filestuff)
    filestuff=file1.readline(20)
    print(filestuff)
    filestuff=file1.readline(20)
    print(filestuff)
# Out:
# satoro
#  gojo is the stronge
# st
#
# in all universe

# %%
with open("example.txt",'r') as file1:
    filestuff=file1.readlines()
    print(filestuff)
# Out:
# ['satoro gojo is the strongest\n', 'in all universe \n', 'in all eternity']

# %%
with open("example.txt",'r') as file1:
    file1.seek(3)
    filestuff=file1.readline()
    print(filestuff)
# Out:
# oro gojo is the strongest
