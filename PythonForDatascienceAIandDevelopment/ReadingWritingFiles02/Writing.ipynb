# %%
with open('example.txt','w+') as file1:
    file1.write("in jjk")
    file1.seek(0)
    print(file1.readline())
# Out:
# in jjk

# %%
Lines=["try your best \n","since thats all u can do\n","in this life \n"]
with open("example.txt",'w+') as file1:
    for line in Lines:
        file1.write(line)

    file1.seek(0)
    print(file1.read())
# Out:
# try your best
# since thats all u can do
# in this life
