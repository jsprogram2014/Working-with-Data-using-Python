# %%
with open("example.txt",'a+') as file1:
    file1.write("you wont feel it now, but work hard, result will be there at the end")
    file1.seek(0)
    print(file1.read())
# Out:
# try your best
# since thats all u can do
# in this life
# you wont feel it now, but work hard, result will be there at the endyou wont feel it now, but work hard, result will be there at the end
