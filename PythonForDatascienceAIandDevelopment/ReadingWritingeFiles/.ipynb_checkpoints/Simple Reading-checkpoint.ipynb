# %%
with open("sample.txt","r") as file1:
    filestuff=file1.read()

print(filestuff)
# Out:
# Messi is the GOAT
# in all realm
# in all soccer

# %%
with open("sample.txt","r") as file1:
    filestuff=file1.readline()
    print(filestuff)
    filestuff=file1.readline()
    print(filestuff)
# Out:
# Messi is the GOAT
