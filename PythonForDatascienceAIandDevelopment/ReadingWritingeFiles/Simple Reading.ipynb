# %%
with open("sample.txt","r") as file1:
    filestuff=file1.read()

print(filestuff)
# Out:
# Messi is the GOAT
# in all realm
# in all soccer

# %%
with open("sample.txt","r") as file1:
    filestuff=file1.readline()
    print(filestuff)
    filestuff=file1.readline()
    print(filestuff)
    filestuff=file1.readline()
    print(filestuff)
    print(filestuff[0])
# Out:
# Messi is the GOAT
#
# in all realm
#
# in all soccer
#
# i

# %%
with open("sample.txt","r") as file1:
    for line in file1:
        print(line)
# Out:
# Messi is the GOAT
#
# in all realm
#
# in all soccer
