# %%
## filtering HTML doc for better data analysis and extraction

from bs4 import BeautifulSoup

table="<table><tr><td id='flight'>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"
soup=BeautifulSoup(table,'html.parser')


## going to find href 
findhref=soup.find_all(href='https://en.wikipedia.org/wiki/Florida')
# print(findhref[0])

## going to find all a tags without href
hrefwa=soup.find_all(lambda tag: tag.name == 'a' and not tag.has_attr('href'))
# print(hrefwa)

# going to find all elements that doesnt contain any links
hregwa=soup.find_all(lambda tag: tag.name !='a' and not tag.find('a'))
# print(hregwa)

## element with id attribute boldest
ele1=soup.find_all(id='flight')
# print(ele1)

## find elements that contain the word string
ele2=soup.find_all(string='Florida')
print(ele2[0].parent)
# Out:
# <a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>

# %%
from bs4 import BeautifulSoup
import requests

two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"
soup=BeautifulSoup(two_tables,'html.parser')

## finding elements using their classes
secondtable=soup.find('table',class_='pizza')
# print(secondtable)


## scraping and downloading the contents of a webpage
url="http://www.ibm.com"
data=requests.get(url).text

soup2=BeautifulSoup(data,'html.parser')

# going to scrap all the links\

for link in soup2.find_all(lambda tag: tag.name=='a' and tag.has_attr('href')):
    # print(link.get('href'))
    a=''
# print(soup2.prettify())
# going to scrap all the image tags

for img in soup2.find_all('img'):
    print(img.get('src'))
# Out:
# https://assets.ibm.com/is/image/ibm/techxchange-banner_sydney?ts=1763573482787&dpr=off
# https://assets.ibm.com/is/image/ibm/72b57d36-f208-48f5-be289492607ff166?ts=1763391426734&dpr=off
# https://assets.ibm.com/is/image/ibm/watsonxassistant_insurance_1x1?ts=1763391504796&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm_maximo_iso_1x1_detail?ts=1763391567243&dpr=off
# https://assets.ibm.com/is/image/ibm/spss-statistics_modeler_1x1?ts=1763132000297&dpr=off
# https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1758917776718&dpr=off
