# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

barcapage=requests.get('https://www.fcbarcelona.com/en/football/first-team/results')
barcasoup=BeautifulSoup(barcapage.text,'html.parser')

# not all table looking are tables
dfs=pd.read_html('https://www.fcbarcelona.com/en/football/first-team/results')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       5 barcapage=requests.get('https://www.fcbarcelona.com/en/football/first-team/results')
#       6 barcasoup=BeautifulSoup(barcapage.text,'html.parser')
# ----> 8 dfs=pd.read_html('https://www.fcbarcelona.com/en/football/first-team/results')
#
# File ~/Projects/my-notebooks/.venv/lib/python3.13/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
# ...
