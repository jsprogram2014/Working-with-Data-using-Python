# %%
import requests

# just using the python library 'requests' for sending api requests

r=requests.get('http://www.ibm.com')

# print(r.status_code) #this is from the response object
# print(r.request.headers)
# print(r.request.body) # this is from the response object also but in the request dict contained in the response object before or after the response is received

# print(r.headers)

# print(r.text) ## printing the content on text string returned as a response

# will be testing out sending a modified get request to receive a modified response since most of the time we want a particular resource not all of them
# we will be pointing out the resource we want using the params

url='http://httpbin.org/get'
params={'name':'joseph','ID':'123'}

r1=requests.get(url,params)
# print(r1.request.body)
# print(r1.status_code)
# print(r1.url)

# content content type is in json i can use json method to get the dict
# print(r1.text)
# print(r1.headers['Content-Type'])
# print(r1.json()['args'])

# we will be doing post request, and can only send the data in post request using body

url='http://httpbin.org/post'
payload={'name':'joseph','ID':'123'}

r1post=requests.post(url,data=payload)

print(r1post.request.body)
# Out:
# name=joseph&ID=123
